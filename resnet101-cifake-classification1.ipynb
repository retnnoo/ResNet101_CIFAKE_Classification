# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import matplotlib.image as mpimg
import tensorflow as tf
from tensorflow.keras import layers, regularizers
from tensorflow.keras.preprocessing import image_dataset_from_directory
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
# Out:
# 2025-11-03 06:02:11.655029: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762149731.840548      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762149731.901724      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
dataset_dir = "/kaggle/input/cifake-real-and-ai-generated-synthetic-images"

train_dir = dataset_dir + "/train"
test_dir = dataset_dir + "/test"

print("Dataset train path:", train_dir)
print("Dataset test path:", test_dir)
# Out:
# Dataset train path: /kaggle/input/cifake-real-and-ai-generated-synthetic-images/train
# Dataset test path: /kaggle/input/cifake-real-and-ai-generated-synthetic-images/test

# %%
# Ambil beberapa contoh file dari masing-masing kelas
classes = ['REAL', 'FAKE']

def show_examples(base_dir, title):
    fig, axes = plt.subplots(1, 4, figsize=(10, 3))
    fig.suptitle(title, fontsize=12)

    for i, cls in enumerate(classes):
        cls_dir = os.path.join(base_dir, cls)
        sample_files = random.sample(os.listdir(cls_dir), 2)
        for j, img_name in enumerate(sample_files):
            img_path = os.path.join(cls_dir, img_name)
            img = mpimg.imread(img_path)
            ax = axes[i*2 + j]
            ax.imshow(img)
            ax.set_title(f"{cls}")
            ax.axis('off')

    plt.tight_layout()
    plt.show()

# Tampilkan contoh dari train dan test
show_examples(train_dir, "Train Dataset Samples")
show_examples(test_dir, "Test Dataset Samples")

# %%
img_height = 32
img_width = 32
batch_size = 64
seed = 42

#load data folder train
full_train_ds = image_dataset_from_directory(
    train_dir,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    shuffle=True,
    seed=seed
)

#Split 90% train dan 10% val
total_batches = tf.data.experimental.cardinality(full_train_ds).numpy()
val_batches = int(total_batches * 0.1)
train_batches = total_batches - val_batches

train_ds = full_train_ds.take(train_batches)
val_ds = full_train_ds.skip(train_batches)

#Load data test dari folder test (tidak diubah atau diacak)
test_ds = image_dataset_from_directory(
    test_dir,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    shuffle=False
)

#Optimasi pipeline
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

def count_images(dataset):
    return sum(batch[0].shape[0] for batch in dataset)

train_count = count_images(train_ds)
val_count = count_images(val_ds)
test_count = count_images(test_ds)

print("Dataset summary:")
print(f"Total batch di folder train: {total_batches}")
print(f"Train batches (90%): {train_batches}")
print(f"Validation batches (10%): {val_batches}")
print(f"Jumlah gambar:")
print(f"Train images: {train_count}")
print(f"Validation images: {val_count}")
print(f"Test images: {test_count}")
# Out:
# Found 100000 files belonging to 2 classes.
# I0000 00:00:1762149890.221654      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 20000 files belonging to 2 classes.
# Dataset summary:
# Total batch di folder train: 1563
# Train batches (90%): 1407
# Validation batches (10%): 156
# Jumlah gambar:
# Train images: 90048
# Validation images: 9952
# Test images: 20000

# %%
# Augmentasi Data (Train Saja)
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y))

# %%
for images, labels in train_ds.take(1):
    plt.figure(figsize=(10, 10))
    for i in range(9):
        augmented = data_augmentation(images)
        plt.subplot(3, 3, i+1)
        plt.imshow(tf.cast(augmented[i], tf.uint8))
        plt.axis("off")
    plt.suptitle("Contoh Gambar Setelah Augmentasi", fontsize=16)
    plt.show()

# %%
imagenet = "/kaggle/input/imagenet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5"

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers

# ResNet101 (tanpa pretrained weights)
base_model = tf.keras.applications.ResNet101(
    include_top=False,
    weights=imagenet,
    input_shape=(img_height, img_width, 3),
    pooling='max'
)

base_model.trainable = True

inputs = tf.keras.Input(shape=(img_height, img_width, 3))
x = base_model(inputs, training=False)
x = layers.BatchNormalization()(x)
x = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = layers.Dropout(0.4)(x)
x = layers.Dense(64, activation='relu')(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

model = tf.keras.Model(inputs, outputs)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet101 (Functional)          │ (None, 2048)           │    42,658,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 2048)           │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 43,207,425 (164.82 MB)
#  Trainable params: 43,097,985 (164.41 MB)
#  Non-trainable params: 109,440 (427.50 KB)

# %%
# Training dengan EarlyStopping
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True
)

# Training model
history = model.fit(
    train_ds.shuffle(1024),
    validation_data=val_ds,
    epochs=100,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1762150219.076014      66 service.cc:148] XLA service 0xf8bbcf0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1762150219.076929      66 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1762150228.259741      66 cuda_dnn.cc:529] Loaded cuDNN version 90300
#
100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 103s 64ms/step - accuracy: 0.9145 - loss: 0.2145 - precision: 0.9114 - recall: 0.9188 - val_accuracy: 0.8894 - val_loss: 0.2900 - val_precision: 0.9852 - val_recall: 0.7872
# Epoch 19/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 102s 63ms/step - accuracy: 0.9234 - loss: 0.1978 - precision: 0.9203 - recall: 0.9285 - val_accuracy: 0.8505 - val_loss: 0.9289 - val_precision: 0.9566 - val_recall: 0.7294
# Epoch 20/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 102s 63ms/step - accuracy: 0.9192 - loss: 0.2112 - precision: 0.9166 - recall: 0.9230 - val_accuracy: 0.8930 - val_loss: 0.2925 - val_precision: 0.9793 - val_recall: 0.7996
# Epoch 21/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 103s 64ms/step - accuracy: 0.9321 - loss: 0.1779 - precision: 0.9306 - recall: 0.9352 - val_accuracy: 0.8782 - val_loss: 2.3568 - val_precision: 0.9902 - val_recall: 0.7603
# Epoch 22/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 101s 63ms/step - accuracy: 0.9371 - loss: 0.1671 - precision: 0.9357 - recall: 0.9388 - val_accuracy: 0.8347 - val_loss: 0.5016 - val_precision: 0.9800 - val_recall: 0.6782
# Epoch 23/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 103s 64ms/step - accuracy: 0.9314 - loss: 0.1793 - precision: 0.9275 - recall: 0.9362 - val_accuracy: 0.7015 - val_loss: 0.8955 - val_precision: 0.9735 - val_recall: 0.4048
# Epoch 24/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 102s 64ms/step - accuracy: 0.9409 - loss: 0.1571 - precision: 0.9398 - recall: 0.9418 - val_accuracy: 0.9101 - val_loss: 0.2225 - val_precision: 0.9760 - val_recall: 0.8380
# Epoch 25/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 104s 65ms/step - accuracy: 0.9444 - loss: 0.1489 - precision: 0.9447 - recall: 0.9439 - val_accuracy: 0.9049 - val_loss: 0.2508 - val_precision: 0.9689 - val_recall: 0.8337
# Epoch 26/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 105s 65ms/step - accuracy: 0.9427 - loss: 0.1524 - precision: 0.9430 - recall: 0.9427 - val_accuracy: 0.7133 - val_loss: 0.6693 - val_precision: 0.7210 - val_recall: 0.6817
# Epoch 27/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 105s 66ms/step - accuracy: 0.9289 - loss: 0.1896 - precision: 0.9296 - recall: 0.9284 - val_accuracy: 0.8425 - val_loss: 0.4531 - val_precision: 0.9920 - val_recall: 0.6858
# Epoch 28/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 105s 65ms/step - accuracy: 0.9483 - loss: 0.1380 - precision: 0.9499 - recall: 0.9466 - val_accuracy: 0.8885 - val_loss: 0.2730 - val_precision: 0.9240 - val_recall: 0.8429
# Epoch 29/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 106s 66ms/step - accuracy: 0.9477 - loss: 0.1403 - precision: 0.9510 - recall: 0.9446 - val_accuracy: 0.9320 - val_loss: 0.1715 - val_precision: 0.9187 - val_recall: 0.9455
# Epoch 30/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 105s 65ms/step - accuracy: 0.9540 - loss: 0.1246 - precision: 0.9538 - recall: 0.9545 - val_accuracy: 0.8959 - val_loss: 0.2767 - val_precision: 0.9919 - val_recall: 0.7951
# Epoch 31/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 105s 66ms/step - accuracy: 0.9530 - loss: 0.1260 - precision: 0.9530 - recall: 0.9531 - val_accuracy: 0.7780 - val_loss: 1.5173 - val_precision: 0.9402 - val_recall: 0.5866
# Epoch 32/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 105s 66ms/step - accuracy: 0.9483 - loss: 0.1415 - precision: 0.9495 - recall: 0.9471 - val_accuracy: 0.8134 - val_loss: 0.4648 - val_precision: 0.9964 - val_recall: 0.6233
# Epoch 33/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 106s 66ms/step - accuracy: 0.9554 - loss: 0.1239 - precision: 0.9586 - recall: 0.9521 - val_accuracy: 0.9493 - val_loss: 0.1367 - val_precision: 0.9511 - val_recall: 0.9455
# Epoch 34/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 105s 66ms/step - accuracy: 0.9596 - loss: 0.1116 - precision: 0.9613 - recall: 0.9577 - val_accuracy: 0.9540 - val_loss: 0.1301 - val_precision: 0.9666 - val_recall: 0.9390
# Epoch 35/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 105s 66ms/step - accuracy: 0.9619 - loss: 0.1039 - precision: 0.9618 - recall: 0.9618 - val_accuracy: 0.8389 - val_loss: 0.4303 - val_precision: 0.9943 - val_recall: 0.6768
# Epoch 36/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 105s 66ms/step - accuracy: 0.9556 - loss: 0.1181 - precision: 0.9560 - recall: 0.9553 - val_accuracy: 0.9272 - val_loss: 0.1931 - val_precision: 0.9541 - val_recall: 0.8951
# Epoch 37/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 105s 65ms/step - accuracy: 0.9618 - loss: 0.1024 - precision: 0.9617 - recall: 0.9619 - val_accuracy: 0.8904 - val_loss: 0.3687 - val_precision: 0.9922 - val_recall: 0.7835
# Epoch 38/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 105s 65ms/step - accuracy: 0.9622 - loss: 0.1030 - precision: 0.9625 - recall: 0.9622 - val_accuracy: 0.9237 - val_loss: 0.2560 - val_precision: 0.9246 - val_recall: 0.9202
# Epoch 39/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 105s 66ms/step - accuracy: 0.9603 - loss: 0.1167 - precision: 0.9600 - recall: 0.9607 - val_accuracy: 0.8894 - val_loss: 0.3205 - val_precision: 0.9627 - val_recall: 0.8066
# Epoch 40/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 105s 65ms/step - accuracy: 0.9627 - loss: 0.0989 - precision: 0.9637 - recall: 0.9620 - val_accuracy: 0.9204 - val_loss: 0.2386 - val_precision: 0.9865 - val_recall: 0.8500
# Epoch 41/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 106s 66ms/step - accuracy: 0.9645 - loss: 0.0977 - precision: 0.9654 - recall: 0.9640 - val_accuracy: 0.9527 - val_loss: 0.1296 - val_precision: 0.9644 - val_recall: 0.9386
# Epoch 42/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 105s 66ms/step - accuracy: 0.9670 - loss: 0.0914 - precision: 0.9672 - recall: 0.9670 - val_accuracy: 0.9057 - val_loss: 0.2868 - val_precision: 0.9891 - val_recall: 0.8176
# Epoch 43/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 105s 66ms/step - accuracy: 0.9669 - loss: 0.0926 - precision: 0.9668 - recall: 0.9673 - val_accuracy: 0.9410 - val_loss: 0.1649 - val_precision: 0.9601 - val_recall: 0.9184
# Epoch 44/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 105s 65ms/step - accuracy: 0.9687 - loss: 0.0841 - precision: 0.9680 - recall: 0.9696 - val_accuracy: 0.9411 - val_loss: 0.1729 - val_precision: 0.9791 - val_recall: 0.8996
# Epoch 45/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 103s 64ms/step - accuracy: 0.9687 - loss: 0.0900 - precision: 0.9670 - recall: 0.9705 - val_accuracy: 0.9359 - val_loss: 0.1953 - val_precision: 0.9883 - val_recall: 0.8802
# Epoch 46/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 103s 64ms/step - accuracy: 0.9705 - loss: 0.0798 - precision: 0.9696 - recall: 0.9715 - val_accuracy: 0.7262 - val_loss: 0.7756 - val_precision: 0.9780 - val_recall: 0.4542
# Epoch 47/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 104s 64ms/step - accuracy: 0.9718 - loss: 0.0809 - precision: 0.9719 - recall: 0.9716 - val_accuracy: 0.9559 - val_loss: 0.1336 - val_precision: 0.9631 - val_recall: 0.9467
# Epoch 48/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 103s 64ms/step - accuracy: 0.9685 - loss: 0.0875 - precision: 0.9690 - recall: 0.9680 - val_accuracy: 0.8794 - val_loss: 0.4284 - val_precision: 0.9876 - val_recall: 0.7647
# Epoch 49/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 103s 64ms/step - accuracy: 0.9698 - loss: 0.0828 - precision: 0.9693 - recall: 0.9706 - val_accuracy: 0.9255 - val_loss: 0.9948 - val_precision: 0.9815 - val_recall: 0.8651
# Epoch 50/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 103s 64ms/step - accuracy: 0.9604 - loss: 0.1117 - precision: 0.9604 - recall: 0.9609 - val_accuracy: 0.9124 - val_loss: 0.2812 - val_precision: 0.9905 - val_recall: 0.8300
# Epoch 51/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 103s 64ms/step - accuracy: 0.9756 - loss: 0.0676 - precision: 0.9752 - recall: 0.9763 - val_accuracy: 0.9427 - val_loss: 0.1895 - val_precision: 0.9771 - val_recall: 0.9049
# Epoch 52/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 102s 64ms/step - accuracy: 0.9758 - loss: 0.0686 - precision: 0.9746 - recall: 0.9776 - val_accuracy: 0.9426 - val_loss: 0.1730 - val_precision: 0.9756 - val_recall: 0.9061
# Epoch 53/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 103s 64ms/step - accuracy: 0.9769 - loss: 0.0638 - precision: 0.9767 - recall: 0.9772 - val_accuracy: 0.8069 - val_loss: 0.5286 - val_precision: 0.9238 - val_recall: 0.6625
# Epoch 54/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 102s 63ms/step - accuracy: 0.9637 - loss: 0.1071 - precision: 0.9631 - recall: 0.9643 - val_accuracy: 0.9001 - val_loss: 0.5033 - val_precision: 0.9937 - val_recall: 0.8023
# Epoch 55/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 103s 64ms/step - accuracy: 0.9776 - loss: 0.0646 - precision: 0.9771 - recall: 0.9780 - val_accuracy: 0.9405 - val_loss: 0.1827 - val_precision: 0.9734 - val_recall: 0.9039
# Epoch 56/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 102s 63ms/step - accuracy: 0.9709 - loss: 0.0829 - precision: 0.9696 - recall: 0.9724 - val_accuracy: 0.6135 - val_loss: 4.8344 - val_precision: 0.9935 - val_recall: 0.2167
# Epoch 57/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 101s 63ms/step - accuracy: 0.9426 - loss: 0.1511 - precision: 0.9404 - recall: 0.9456 - val_accuracy: 0.8983 - val_loss: 0.5212 - val_precision: 0.9942 - val_recall: 0.7982
# Epoch 58/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 99s 61ms/step - accuracy: 0.9714 - loss: 0.0810 - precision: 0.9717 - recall: 0.9711 - val_accuracy: 0.9144 - val_loss: 1.2688 - val_precision: 0.9922 - val_recall: 0.8327
# Epoch 59/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 99s 61ms/step - accuracy: 0.9772 - loss: 0.0664 - precision: 0.9776 - recall: 0.9768 - val_accuracy: 0.8878 - val_loss: 0.5327 - val_precision: 0.9896 - val_recall: 0.7802
# Epoch 60/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 100s 62ms/step - accuracy: 0.9760 - loss: 0.0696 - precision: 0.9766 - recall: 0.9757 - val_accuracy: 0.9449 - val_loss: 0.2854 - val_precision: 0.9664 - val_recall: 0.9202
# Epoch 61/100
# 1407/1407 ━━━━━━━━━━━━━━━━━━━━ 100s 62ms/step - accuracy: 0.9479 - loss: 0.1385 - precision: 0.9446 - recall: 0.9516 - val_accuracy: 0.9374 - val_loss: 0.2001 - val_precision: 0.9837 - val_recall: 0.8876

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.title("Accuracy over Epochs")

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title("Loss over Epochs")

plt.show()

# %%
# Evaluasi di Data Test

test_loss, test_acc, test_prec, test_rec = model.evaluate(test_ds, verbose=1)
print(f"\nTest Accuracy: {test_acc:.4f}")
print(f"Test Precision: {test_prec:.4f}")
print(f"Test Recall: {test_rec:.4f}")

y_true = np.concatenate([y for x, y in test_ds], axis=0)

y_pred = model.predict(test_ds)
y_pred_classes = (y_pred.flatten() > 0.5).astype("int32")  # threshold 0.5

# Confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',xticklabels=['FAKE', 'REAL'], yticklabels=['FAKE', 'REAL'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred_classes, target_names=['FAKE', 'REAL']))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9602 - loss: 0.1152 - precision: 0.4412 - recall: 0.4717
#
# Test Accuracy: 0.9509
# Test Precision: 0.9633
# Test Recall: 0.9374
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 44ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#         FAKE       0.94      0.96      0.95     10000
#         REAL       0.96      0.94      0.95     10000
#
#     accuracy                           0.95     20000
#    macro avg       0.95      0.95      0.95     20000
# weighted avg       0.95      0.95      0.95     20000

# %%
model.save("/kaggle/working/resnet101_binary.h5")
