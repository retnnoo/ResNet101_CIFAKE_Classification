# %% [markdown]
# <a href="https://www.kaggle.com/code/retno024/bestmodel-resnet101-cifake-classification?scriptVersionId=288995416" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import matplotlib.image as mpimg
import tensorflow as tf
from tensorflow.keras import layers, regularizers
from tensorflow.keras.preprocessing import image_dataset_from_directory
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
# Out:
# 2025-12-29 05:43:48.185861: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766987028.369670      20 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766987028.422427      20 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
dataset_dir = "/kaggle/input/cifake-real-and-ai-generated-synthetic-images"

train_dir = dataset_dir + "/train"
test_dir = dataset_dir + "/test"

print("Dataset train path:", train_dir)
print("Dataset test path:", test_dir)
# Out:
# Dataset train path: /kaggle/input/cifake-real-and-ai-generated-synthetic-images/train
# Dataset test path: /kaggle/input/cifake-real-and-ai-generated-synthetic-images/test

# %%
# Ambil beberapa contoh file dari masing-masing kelas
classes = ['REAL', 'FAKE']

def show_examples(base_dir, title):
    fig, axes = plt.subplots(1, 4, figsize=(10, 3))
    fig.suptitle(title, fontsize=12)

    for i, cls in enumerate(classes):
        cls_dir = os.path.join(base_dir, cls)
        sample_files = random.sample(os.listdir(cls_dir), 2)
        for j, img_name in enumerate(sample_files):
            img_path = os.path.join(cls_dir, img_name)
            img = mpimg.imread(img_path)
            ax = axes[i*2 + j]
            ax.imshow(img)
            ax.set_title(f"{cls}")
            ax.axis('off')

    plt.tight_layout()
    plt.show()

# Tampilkan contoh dari train dan test
show_examples(train_dir, "Train Dataset Samples")
show_examples(test_dir, "Test Dataset Samples")

# %%
img_height = 32
img_width = 32
batch_size = 32
seed = 42

#load data folder train
full_train_ds = image_dataset_from_directory(
    train_dir,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    shuffle=True,
    seed=seed
)

#Split 90% train dan 10% val
total_batches = tf.data.experimental.cardinality(full_train_ds).numpy()
val_batches = int(total_batches * 0.1)
train_batches = total_batches - val_batches

train_ds = full_train_ds.take(train_batches)
val_ds = full_train_ds.skip(train_batches)

#Load data test dari folder test (tidak diubah atau diacak)
test_ds = image_dataset_from_directory(
    test_dir,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    shuffle=False
)

#Optimasi pipeline
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

def count_images(dataset):
    return sum(batch[0].shape[0] for batch in dataset)

train_count = count_images(train_ds)
val_count = count_images(val_ds)
test_count = count_images(test_ds)

print("Dataset summary:")
print(f"Total batch di folder train: {total_batches}")
print(f"Train batches (90%): {train_batches}")
print(f"Validation batches (10%): {val_batches}")
print(f"Jumlah gambar:")
print(f"Train images: {train_count}")
print(f"Validation images: {val_count}")
print(f"Test images: {test_count}")
# Out:
# Found 100000 files belonging to 2 classes.
# I0000 00:00:1766987154.536420      20 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 20000 files belonging to 2 classes.
# Dataset summary:
# Total batch di folder train: 3125
# Train batches (90%): 2813
# Validation batches (10%): 312
# Jumlah gambar:
# Train images: 90016
# Validation images: 9984
# Test images: 20000

# %%
# Augmentasi Data (Train Saja)
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y))

# %%
for images, labels in train_ds.take(1):
    plt.figure(figsize=(10, 10))
    for i in range(9):
        augmented = data_augmentation(images)
        plt.subplot(3, 3, i+1)
        plt.imshow(tf.cast(augmented[i], tf.uint8))
        plt.axis("off")
    plt.suptitle("Contoh Gambar Setelah Augmentasi", fontsize=16)
    plt.show()

# %%
imagenet = "/kaggle/input/imagenet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5"

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers

# ==== PREPROCESSING ====
preprocess = tf.keras.applications.resnet.preprocess_input
base_model = tf.keras.applications.ResNet101(
    include_top=False,
    weights=imagenet,
    input_shape=(img_height, img_width, 3),
    pooling='avg'
)

base_model.trainable = False    # freeze semua layer

inputs = tf.keras.Input(shape=(img_height, img_width, 3))
x = layers.Lambda(preprocess)(inputs)
x = base_model(x, training=False)

# Fully connected head
x = layers.BatchNormalization()(x)
x = layers.Dense(512, activation='relu',kernel_regularizer=regularizers.l2(1e-4))(x)
x = layers.Dropout(0.5)(x)

outputs = layers.Dense(1, activation='sigmoid')(x)

model = tf.keras.Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss='binary_crossentropy',
    metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet101 (Functional)          │ (None, 2048)           │    42,658,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 2048)           │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 43,715,969 (166.76 MB)
#  Trainable params: 1,053,697 (4.02 MB)
#  Non-trainable params: 42,662,272 (162.74 MB)

# %%
# Training dengan EarlyStopping
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True
)

# Training model
history = model.fit(
    train_ds.shuffle(1024),
    validation_data=val_ds,
    epochs=150,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/150
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1766987369.897458      67 service.cc:148] XLA service 0x34717e70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1766987369.898312      67 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1766987372.751541      67 cuda_dnn.cc:529] Loaded cuDNN version 90300
#    7/2813 ━━━━━━━━━━━━━━━━━━━━ 49s 17ms/step - accuracy: 0.4318 - loss: 1.1226 - precision: 0.4404 - recall: 0.5000
# I0000 00:00:1766987376.434863      67 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 91s 20ms/step - accuracy: 0.6851 - loss: 0.7197 - precision: 0.6844 - recall: 0.6940 - val_accuracy: 0.8506 - val_loss: 0.4276 - val_precision: 0.8761 - val_recall: 0.8108
# Epoch 2/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 55s 17ms/step - accuracy: 0.8099 - loss: 0.5172 - precision: 0.8074 - recall: 0.8137 - val_accuracy: 0.8647 - val_loss: 0.3982 - val_precision: 0.8909 - val_recall: 0.8261
# Epoch 3/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 55s 17ms/step - accuracy: 0.8268 - loss: 0.4805 - precision: 0.8237 - recall: 0.8302 - val_accuracy: 0.8713 - val_loss: 0.3856 - val_precision: 0.9041 - val_recall: 0.8259
# Epoch 4/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 17ms/step - accuracy: 0.8324 - loss: 0.4628 - precision: 0.8314 - recall: 0.8346 - val_accuracy: 0.8755 - val_loss: 0.3736 - val_precision: 0.9074 - val_recall: 0.8318
# Epoch 5/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 55s 17ms/step - accuracy: 0.8412 - loss: 0.4478 - precision: 0.8389 - recall: 0.8432 - val_accuracy: 0.8774 - val_loss: 0.3676 - val_precision: 0.9094 - val_recall: 0.8338
# Epoch 6/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━
150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 18ms/step - accuracy: 0.8995 - loss: 0.2958 - precision: 0.8988 - recall: 0.9003 - val_accuracy: 0.9092 - val_loss: 0.2764 - val_precision: 0.9416 - val_recall: 0.8693
# Epoch 79/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9000 - loss: 0.2946 - precision: 0.8973 - recall: 0.9032 - val_accuracy: 0.9082 - val_loss: 0.2785 - val_precision: 0.9436 - val_recall: 0.8650
# Epoch 80/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9002 - loss: 0.2926 - precision: 0.9000 - recall: 0.9012 - val_accuracy: 0.9072 - val_loss: 0.2754 - val_precision: 0.9407 - val_recall: 0.8658
# Epoch 81/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.8991 - loss: 0.2944 - precision: 0.8965 - recall: 0.9016 - val_accuracy: 0.9077 - val_loss: 0.2777 - val_precision: 0.9433 - val_recall: 0.8642
# Epoch 82/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 82s 18ms/step - accuracy: 0.8991 - loss: 0.2926 - precision: 0.8972 - recall: 0.9024 - val_accuracy: 0.9096 - val_loss: 0.2744 - val_precision: 0.9420 - val_recall: 0.8697
# Epoch 83/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9011 - loss: 0.2942 - precision: 0.8985 - recall: 0.9048 - val_accuracy: 0.9085 - val_loss: 0.2765 - val_precision: 0.9444 - val_recall: 0.8648
# Epoch 84/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9027 - loss: 0.2872 - precision: 0.9027 - recall: 0.9035 - val_accuracy: 0.9089 - val_loss: 0.2735 - val_precision: 0.9407 - val_recall: 0.8695
# Epoch 85/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9019 - loss: 0.2882 - precision: 0.8991 - recall: 0.9054 - val_accuracy: 0.9090 - val_loss: 0.2732 - val_precision: 0.9439 - val_recall: 0.8664
# Epoch 86/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 18ms/step - accuracy: 0.9022 - loss: 0.2872 - precision: 0.9007 - recall: 0.9055 - val_accuracy: 0.9087 - val_loss: 0.2725 - val_precision: 0.9417 - val_recall: 0.8681
# Epoch 87/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9008 - loss: 0.2888 - precision: 0.8995 - recall: 0.9034 - val_accuracy: 0.9080 - val_loss: 0.2750 - val_precision: 0.9461 - val_recall: 0.8619
# Epoch 88/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9013 - loss: 0.2894 - precision: 0.8997 - recall: 0.9018 - val_accuracy: 0.9093 - val_loss: 0.2736 - val_precision: 0.9422 - val_recall: 0.8689
# Epoch 89/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9016 - loss: 0.2881 - precision: 0.8978 - recall: 0.9058 - val_accuracy: 0.9086 - val_loss: 0.2731 - val_precision: 0.9430 - val_recall: 0.8664
# Epoch 90/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 18ms/step - accuracy: 0.9023 - loss: 0.2875 - precision: 0.9009 - recall: 0.9048 - val_accuracy: 0.9099 - val_loss: 0.2690 - val_precision: 0.9395 - val_recall: 0.8729
# Epoch 91/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9035 - loss: 0.2830 - precision: 0.9017 - recall: 0.9059 - val_accuracy: 0.9091 - val_loss: 0.2723 - val_precision: 0.9421 - val_recall: 0.8685
# Epoch 92/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9029 - loss: 0.2840 - precision: 0.9022 - recall: 0.9044 - val_accuracy: 0.9104 - val_loss: 0.2708 - val_precision: 0.9417 - val_recall: 0.8717
# Epoch 93/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9029 - loss: 0.2822 - precision: 0.9004 - recall: 0.9049 - val_accuracy: 0.9100 - val_loss: 0.2694 - val_precision: 0.9399 - val_recall: 0.8727
# Epoch 94/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 17ms/step - accuracy: 0.9036 - loss: 0.2846 - precision: 0.9015 - recall: 0.9068 - val_accuracy: 0.9093 - val_loss: 0.2707 - val_precision: 0.9423 - val_recall: 0.8687
# Epoch 95/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 18ms/step - accuracy: 0.9048 - loss: 0.2803 - precision: 0.9021 - recall: 0.9082 - val_accuracy: 0.9098 - val_loss: 0.2691 - val_precision: 0.9397 - val_recall: 0.8725
# Epoch 96/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9034 - loss: 0.2836 - precision: 0.9019 - recall: 0.9047 - val_accuracy: 0.9117 - val_loss: 0.2666 - val_precision: 0.9401 - val_recall: 0.8762
# Epoch 97/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9071 - loss: 0.2759 - precision: 0.9041 - recall: 0.9107 - val_accuracy: 0.9110 - val_loss: 0.2676 - val_precision: 0.9414 - val_recall: 0.8733
# Epoch 98/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 18ms/step - accuracy: 0.9034 - loss: 0.2807 - precision: 0.9031 - recall: 0.9037 - val_accuracy: 0.9096 - val_loss: 0.2710 - val_precision: 0.9467 - val_recall: 0.8648
# Epoch 99/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9053 - loss: 0.2771 - precision: 0.9033 - recall: 0.9069 - val_accuracy: 0.9104 - val_loss: 0.2639 - val_precision: 0.9382 - val_recall: 0.8754
# Epoch 100/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 17ms/step - accuracy: 0.9050 - loss: 0.2781 - precision: 0.9040 - recall: 0.9067 - val_accuracy: 0.9100 - val_loss: 0.2681 - val_precision: 0.9420 - val_recall: 0.8705
# Epoch 101/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9039 - loss: 0.2788 - precision: 0.9028 - recall: 0.9059 - val_accuracy: 0.9093 - val_loss: 0.2683 - val_precision: 0.9451 - val_recall: 0.8658
# Epoch 102/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9043 - loss: 0.2792 - precision: 0.9030 - recall: 0.9061 - val_accuracy: 0.9101 - val_loss: 0.2671 - val_precision: 0.9436 - val_recall: 0.8691
# Epoch 103/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 18ms/step - accuracy: 0.9074 - loss: 0.2752 - precision: 0.9065 - recall: 0.9089 - val_accuracy: 0.9124 - val_loss: 0.2641 - val_precision: 0.9423 - val_recall: 0.8754
# Epoch 104/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9074 - loss: 0.2727 - precision: 0.9058 - recall: 0.9094 - val_accuracy: 0.9107 - val_loss: 0.2684 - val_precision: 0.9445 - val_recall: 0.8695
# Epoch 105/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 17ms/step - accuracy: 0.9058 - loss: 0.2750 - precision: 0.9045 - recall: 0.9075 - val_accuracy: 0.9108 - val_loss: 0.2648 - val_precision: 0.9437 - val_recall: 0.8705
# Epoch 106/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 18ms/step - accuracy: 0.9051 - loss: 0.2757 - precision: 0.9039 - recall: 0.9072 - val_accuracy: 0.9096 - val_loss: 0.2676 - val_precision: 0.9443 - val_recall: 0.8672
# Epoch 107/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9064 - loss: 0.2721 - precision: 0.9041 - recall: 0.9092 - val_accuracy: 0.9112 - val_loss: 0.2627 - val_precision: 0.9412 - val_recall: 0.8740
# Epoch 108/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9066 - loss: 0.2765 - precision: 0.9039 - recall: 0.9104 - val_accuracy: 0.9102 - val_loss: 0.2677 - val_precision: 0.9454 - val_recall: 0.8674
# Epoch 109/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9070 - loss: 0.2710 - precision: 0.9061 - recall: 0.9087 - val_accuracy: 0.9110 - val_loss: 0.2648 - val_precision: 0.9451 - val_recall: 0.8695
# Epoch 110/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 18ms/step - accuracy: 0.9080 - loss: 0.2715 - precision: 0.9056 - recall: 0.9105 - val_accuracy: 0.9099 - val_loss: 0.2611 - val_precision: 0.9407 - val_recall: 0.8717
# Epoch 111/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9079 - loss: 0.2684 - precision: 0.9057 - recall: 0.9103 - val_accuracy: 0.9111 - val_loss: 0.2626 - val_precision: 0.9437 - val_recall: 0.8711
# Epoch 112/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9093 - loss: 0.2685 - precision: 0.9076 - recall: 0.9121 - val_accuracy: 0.9109 - val_loss: 0.2652 - val_precision: 0.9455 - val_recall: 0.8689
# Epoch 113/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 18ms/step - accuracy: 0.9091 - loss: 0.2703 - precision: 0.9090 - recall: 0.9109 - val_accuracy: 0.9103 - val_loss: 0.2645 - val_precision: 0.9454 - val_recall: 0.8676
# Epoch 114/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9097 - loss: 0.2670 - precision: 0.9058 - recall: 0.9138 - val_accuracy: 0.9113 - val_loss: 0.2622 - val_precision: 0.9442 - val_recall: 0.8711
# Epoch 115/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 18ms/step - accuracy: 0.9106 - loss: 0.2657 - precision: 0.9086 - recall: 0.9141 - val_accuracy: 0.9116 - val_loss: 0.2619 - val_precision: 0.9422 - val_recall: 0.8738
# Epoch 116/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 18ms/step - accuracy: 0.9099 - loss: 0.2667 - precision: 0.9066 - recall: 0.9133 - val_accuracy: 0.9110 - val_loss: 0.2618 - val_precision: 0.9445 - val_recall: 0.8701
# Epoch 117/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9100 - loss: 0.2626 - precision: 0.9074 - recall: 0.9132 - val_accuracy: 0.9119 - val_loss: 0.2609 - val_precision: 0.9450 - val_recall: 0.8715
# Epoch 118/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 18ms/step - accuracy: 0.9110 - loss: 0.2650 - precision: 0.9117 - recall: 0.9115 - val_accuracy: 0.9114 - val_loss: 0.2596 - val_precision: 0.9424 - val_recall: 0.8731
# Epoch 119/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9117 - loss: 0.2612 - precision: 0.9090 - recall: 0.9151 - val_accuracy: 0.9094 - val_loss: 0.2630 - val_precision: 0.9435 - val_recall: 0.8676
# Epoch 120/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 18ms/step - accuracy: 0.9093 - loss: 0.2673 - precision: 0.9074 - recall: 0.9127 - val_accuracy: 0.9107 - val_loss: 0.2627 - val_precision: 0.9459 - val_recall: 0.8681
# Epoch 121/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9119 - loss: 0.2607 - precision: 0.9098 - recall: 0.9139 - val_accuracy: 0.9123 - val_loss: 0.2609 - val_precision: 0.9439 - val_recall: 0.8735
# Epoch 122/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9109 - loss: 0.2631 - precision: 0.9078 - recall: 0.9137 - val_accuracy: 0.9107 - val_loss: 0.2647 - val_precision: 0.9467 - val_recall: 0.8672
# Epoch 123/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9102 - loss: 0.2652 - precision: 0.9089 - recall: 0.9124 - val_accuracy: 0.9106 - val_loss: 0.2615 - val_precision: 0.9451 - val_recall: 0.8687
# Epoch 124/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9115 - loss: 0.2632 - precision: 0.9103 - recall: 0.9134 - val_accuracy: 0.9112 - val_loss: 0.2626 - val_precision: 0.9463 - val_recall: 0.8687
# Epoch 125/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 58s 18ms/step - accuracy: 0.9107 - loss: 0.2614 - precision: 0.9087 - recall: 0.9129 - val_accuracy: 0.9130 - val_loss: 0.2578 - val_precision: 0.9422 - val_recall: 0.8768
# Epoch 126/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━
150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 18ms/step - accuracy: 0.9149 - loss: 0.2497 - precision: 0.9135 - recall: 0.9170 - val_accuracy: 0.9131 - val_loss: 0.2545 - val_precision: 0.9456 - val_recall: 0.8735
# Epoch 143/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 18ms/step - accuracy: 0.9138 - loss: 0.2504 - precision: 0.9126 - recall: 0.9168 - val_accuracy: 0.9134 - val_loss: 0.2525 - val_precision: 0.9421 - val_recall: 0.8778
# Epoch 144/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9141 - loss: 0.2538 - precision: 0.9130 - recall: 0.9150 - val_accuracy: 0.9138 - val_loss: 0.2551 - val_precision: 0.9462 - val_recall: 0.8744
# Epoch 145/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 18ms/step - accuracy: 0.9144 - loss: 0.2505 - precision: 0.9123 - recall: 0.9172 - val_accuracy: 0.9145 - val_loss: 0.2522 - val_precision: 0.9442 - val_recall: 0.8780
# Epoch 146/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9135 - loss: 0.2515 - precision: 0.9132 - recall: 0.9148 - val_accuracy: 0.9136 - val_loss: 0.2515 - val_precision: 0.9437 - val_recall: 0.8766
# Epoch 147/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 18ms/step - accuracy: 0.9141 - loss: 0.2512 - precision: 0.9127 - recall: 0.9161 - val_accuracy: 0.9133 - val_loss: 0.2539 - val_precision: 0.9464 - val_recall: 0.8731
# Epoch 148/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 18ms/step - accuracy: 0.9153 - loss: 0.2486 - precision: 0.9133 - recall: 0.9173 - val_accuracy: 0.9131 - val_loss: 0.2518 - val_precision: 0.9434 - val_recall: 0.8758
# Epoch 149/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 57s 18ms/step - accuracy: 0.9180 - loss: 0.2456 - precision: 0.9163 - recall: 0.9198 - val_accuracy: 0.9121 - val_loss: 0.2521 - val_precision: 0.9460 - val_recall: 0.8709
# Epoch 150/150
# 2813/2813 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - accuracy: 0.9163 - loss: 0.2460 - precision: 0.9159 - recall: 0.9175 - val_accuracy: 0.9134 - val_loss: 0.2536 - val_precision: 0.9452 - val_recall: 0.8746

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.title("Accuracy over Epochs")

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title("Loss over Epochs")

plt.show()

# %%
# Evaluasi di Data Test

test_loss, test_acc, test_prec, test_rec = model.evaluate(test_ds, verbose=1)
print(f"\nTest Accuracy: {test_acc:.4f}")
print(f"Test Precision: {test_prec:.4f}")
print(f"Test Recall: {test_rec:.4f}")

y_true = np.concatenate([y for x, y in test_ds], axis=0)

y_pred = model.predict(test_ds)
y_pred_classes = (y_pred.flatten() > 0.5).astype("int32")  # threshold 0.5

# Confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',xticklabels=['FAKE', 'REAL'], yticklabels=['FAKE', 'REAL'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred_classes, target_names=['FAKE', 'REAL']))
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9394 - loss: 0.1946 - precision: 0.4195 - recall: 0.4390
#
# Test Accuracy: 0.9146
# Test Precision: 0.9473
# Test Recall: 0.8779
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#         FAKE       0.89      0.95      0.92     10000
#         REAL       0.95      0.88      0.91     10000
#
#     accuracy                           0.91     20000
#    macro avg       0.92      0.91      0.91     20000
# weighted avg       0.92      0.91      0.91     20000

# %%
model.save("/kaggle/working/resnet101_binary.h5")
